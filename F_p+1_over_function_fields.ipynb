# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 3

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^3 + 2*x
# F'_{p+1}(x) = 3*x^2 + 2
# Roots of F'_{p+1}(x) = [-0.8164965809277260?*I, 0.8164965809277260?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -0.8164965809277260?*I    F_{p+1}(root) = -1.088662107903635?*I
# root = 0.8164965809277260?*I    F_{p+1}(root) = 1.088662107903635?*I

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 5

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^5 + 4*x^3 + 3*x
# F'_{p+1}(x) = 5*x^4 + 12*x^2 + 3
# Roots of F'_{p+1}(x) = [-1.454824779480735?*I, -0.5324329638638389?*I, 0.5324329638638389?*I, 1.454824779480735?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -1.454824779480735?*I    F_{p+1}(root) = 1.435074401806977?*I
# root = -0.5324329638638389?*I    F_{p+1}(root) = -1.036340417661277?*I
# root = 0.5324329638638389?*I    F_{p+1}(root) = 1.036340417661277?*I
# root = 1.454824779480735?*I    F_{p+1}(root) = -1.435074401806977?*I

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 7

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^7 + 6*x^5 + 10*x^3 + 4*x
# F'_{p+1}(x) = 7*x^6 + 30*x^4 + 30*x^2 + 4
# Roots of F'_{p+1}(x) = [-1.689501207036913?*I, -1.128798962006719?*I, -0.3963746466509361?*I, 0.3963746466509361?*I, 1.128798962006719?*I, 1.689501207036913?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -1.689501207036913?*I    F_{p+1}(root) = -1.833253809196096?*I
# root = -1.128798962006719?*I    F_{p+1}(root) = 1.206984541372626?*I
# root = -0.3963746466509361?*I    F_{p+1}(root) = -1.019911546159360?*I
# root = 0.3963746466509361?*I    F_{p+1}(root) = 1.019911546159360?*I
# root = 1.128798962006719?*I    F_{p+1}(root) = -1.206984541372626?*I
# root = 1.689501207036913?*I    F_{p+1}(root) = 1.833253809196096?*I

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 11

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^11 + 10*x^9 + 36*x^7 + 56*x^5 + 35*x^3 + 6*x
# F'_{p+1}(x) = 11*x^10 + 90*x^8 + 252*x^6 + 280*x^4 + 105*x^2 + 6
# Roots of F'_{p+1}(x) = [-1.860773473768228?*I, -1.597824971366402?*I, -1.226042916814884?*I, -0.7707201598862896?*I, -0.2628779627309330?*I, 0.2628779627309330?*I, 0.7707201598862896?*I, 1.226042916814884?*I, 1.597824971366402?*I, 1.860773473768228?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -1.860773473768228?*I    F_{p+1}(root) = -2.66888082303067?*I
# root = -1.597824971366402?*I    F_{p+1}(root) = 1.65256253530870?*I
# root = -1.226042916814884?*I    F_{p+1}(root) = -1.263079027262197?*I
# root = -0.7707201598862896?*I    F_{p+1}(root) = 1.083042380207401?*I
# root = -0.2628779627309330?*I    F_{p+1}(root) = -1.008690094291205?*I
# root = 0.2628779627309330?*I    F_{p+1}(root) = 1.008690094291205?*I
# root = 0.7707201598862896?*I    F_{p+1}(root) = -1.083042380207401?*I
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 13

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^13 + 12*x^11 + 55*x^9 + 120*x^7 + 126*x^5 + 56*x^3 + 7*x
# F'_{p+1}(x) = 13*x^12 + 132*x^10 + 495*x^8 + 840*x^6 + 630*x^4 + 168*x^2 + 7
# Roots of F'_{p+1}(x) = [-1.897519096291606?*I, 0.?e-48 - 1.702151946999243?*I, -1.421472208765074?*I, -1.069522747604337?*I, -0.6639459580560955?*I, -0.2250773183328708?*I, 0.2250773183328708?*I, 0.6639459580560955?*I, 1.069522747604337?*I, 1.421472208765074?*I, 0.?e-48 + 1.702151946999243?*I, 1.897519096291606?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -1.897519096291606?*I    F_{p+1}(root) = 3.094212631512?*I
# root = 0.?e-48 - 1.702151946999243?*I    F_{p+1}(root) = 0.?e-44 - 1.891968093346?*I
# root = -1.421472208765074?*I    F_{p+1}(root) = 1.4178600754850?*I
# root = -1.069522747604337?*I    F_{p+1}(root) = -1.18222034148204?*I
# root = -0.6639459580560955?*I    F_{p+1}(root) = 1.059785814858842?*I
# root = -0.2250773183328708?*I    F_{p+1}(root) = -1.006360336641021?*I
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 17

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^17 + 16*x^15 + 105*x^13 + 364*x^11 + 715*x^9 + 792*x^7 + 462*x^5 + 120*x^3 + 9*x
# F'_{p+1}(x) = 17*x^16 + 240*x^14 + 1365*x^12 + 4004*x^10 + 6435*x^8 + 5544*x^6 + 2310*x^4 + 360*x^2 + 9
# Roots of F'_{p+1}(x) = [-1.937878127142588?*I, -1.818240978817230?*I, -1.643381633094748?*I, -1.418594207223810?*I, -1.150705332514494?*I, -0.8478536495784505?*I, -0.5192407444823521?*I, -0.1748511516751981?*I, 0.1748511516751981?*I, 0.5192407444823521?*I, 0.8478536495784505?*I, 1.150705332514494?*I, 1.418594207223810?*I, 1.643381633094748?*I, 1.818240978817230?*I, 1.937878127142588?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -1.937878127142588?*I    F_{p+1}(root) = 3.951157256?*I
# root = -1.818240978817230?*I    F_{p+1}(root) = -2.383312124?*I
# root = -1.643381633094748?*I    F_{p+1}(root) = 1.7489893861?*I
# root = -1.418594207223810?*I    F_{p+1}(root) = -1.41641012915?*I
# root = -1.150705332514494?*I    F_{p+1}(root) = 1.221702640766?*I
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 23

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^23 + 22*x^21 + 210*x^19 + 1140*x^17 + 3876*x^15 + 8568*x^13 + 12376*x^11 + 11440*x^9 + 6435*x^7 + 2002*x^5 + 286*x^3 + 12*x
# F'_{p+1}(x) = 23*x^22 + 462*x^20 + 3990*x^18 + 19380*x^16 + 58140*x^14 + 111384*x^12 + 136136*x^10 + 102960*x^8 + 45045*x^6 + 10010*x^4 + 858*x^2 + 12
# Roots of F'_{p+1}(x) = [-1.96500843944461?*I, -1.8971623825035?*I, -1.7968687973598?*I, -1.6658331825447?*I, -1.50629569992673?*I, -1.32098551991055?*I, -1.113073134983053?*I, -0.8861158845684059?*I, -0.6439970183369909?*I, -0.3908592268617342?*I, -0.1310337478891995?*I, 0.1310337478891995?*I, 0.3908592268617342?*I, 0.6439970183369909?*I, 0.8861158845684059?*I, 1.113073134983053?*I, 1.32098551991055?*I, 1.50629569992673?*I, 1.6658331825447?*I, 1.7968687973598?*I, 1.8971623825035?*I, 1.96500843944461?*I]
# Values of F_{p+1} at the roots of F'_{p+1}:
# root = -1.96500843944461?*I    F_{p+1}(root) = -5.244209?*I
# root = -1.8971623825035?*I    F_{p+1}(root) = 3.13488?*I
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 29

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^29 + 28*x^27 + 351*x^25 + 2600*x^23 + 12650*x^21 + 42504*x^19 + 100947*x^17 + 170544*x^15 + 203490*x^13 + 167960*x^11 + 92378*x^9 + 31824*x^7 + 6188*x^5 + 560*x^3 + 15*x
# F'_{p+1}(x) = 29*x^28 + 756*x^26 + 8775*x^24 + 59800*x^22 + 265650*x^20 + 807576*x^18 + 1716099*x^16 + 2558160*x^14 + 2645370*x^12 + 1847560*x^10 + 831402*x^8 + 222768*x^6 + 30940*x^4 + 1680*x^2 + 15
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 31

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^31 + 30*x^29 + 406*x^27 + 3276*x^25 + 17550*x^23 + 65780*x^21 + 177100*x^19 + 346104*x^17 + 490314*x^15 + 497420*x^13 + 352716*x^11 + 167960*x^9 + 50388*x^7 + 8568*x^5 + 680*x^3 + 16*x
# F'_{p+1}(x) = 31*x^30 + 870*x^28 + 10962*x^26 + 81900*x^24 + 403650*x^22 + 1381380*x^20 + 3364900*x^18 + 5883768*x^16 + 7354710*x^14 + 6466460*x^12 + 3879876*x^10 + 1511640*x^8 + 352716*x^6 + 42840*x^4 + 2040*x^2 + 16
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 37

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^37 + 36*x^35 + 595*x^33 + 5984*x^31 + 40920*x^29 + 201376*x^27 + 736281*x^25 + 2035800*x^23 + 4292145*x^21 + 6906900*x^19 + 8436285*x^17 + 7726160*x^15 + 5200300*x^13 + 2496144*x^11 + 817190*x^9 + 170544*x^7 + 20349*x^5 + 1140*x^3 + 19*x
# F'_{p+1}(x) = 37*x^36 + 1260*x^34 + 19635*x^32 + 185504*x^30 + 1186680*x^28 + 5437152*x^26 + 18407025*x^24 + 46823400*x^22 + 90135045*x^20 + 131231100*x^18 + 143416845*x^16 + 115892400*x^14 + 67603900*x^12 + 27457584*x^10 + 7354710*x^8 + 1193808*x^6 + 101745*x^4 + 3420*x^2 + 19
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 41

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^41 + 40*x^39 + 741*x^37 + 8436*x^35 + 66045*x^33 + 376992*x^31 + 1623160*x^29 + 5379616*x^27 + 13884156*x^25 + 28048800*x^23 + 44352165*x^21 + 54627300*x^19 + 51895935*x^17 + 37442160*x^15 + 20058300*x^13 + 7726160*x^11 + 2042975*x^9 + 346104*x^7 + 33649*x^5 + 1540*x^3 + 21*x
# F'_{p+1}(x) = 41*x^40 + 1560*x^38 + 27417*x^36 + 295260*x^34 + 2179485*x^32 + 11686752*x^30 + 47071640*x^28 + 145249632*x^26 + 347103900*x^24 + 645122400*x^22 + 931395465*x^20 + 1037918700*x^18 + 882230895*x^16 + 561632400*x^14 + 260757900*x^12 + 84987760*x^10 + 18386775*x^8 + 2422728*x^6 + 168245*x^4 + 4620*x^2 + 21
# ...

# %%
# Polynomial ring
R.<x> = PolynomialRing(QQ)

# Fibonacci polynomial F_n(x)
def fibonacci_polynomial(n):
    if n == 0:
        return R(0)
    if n == 1:
        return R(1)

    F0 = R(0)
    F1 = R(1)

    for k in range(2, n + 1):
        F0, F1 = F1, x*F1 + F0

    return F1


# Compute F_{p+1}, its first derivative, the roots of the derivative,
# and the values of F_{p+1} at those roots
def critical_values_fibonacci(p, root_ring=QQbar):
    F = fibonacci_polynomial(p + 1)
    dF = F.derivative()

    # roots of the first derivative
    roots_dF = dF.roots(ring=root_ring, multiplicities=False)

    # values of F_{p+1} at the roots of F'_{p+1}
    values = [(r, F(r)) for r in roots_dF]

    return F, dF, roots_dF, values


# Example
p = 47

F, dF, roots_dF, values = critical_values_fibonacci(p)

print("F_{p+1}(x) =", F)
print("F'_{p+1}(x) =", dF)
print("Roots of F'_{p+1}(x) =", roots_dF)
print("Values of F_{p+1} at the roots of F'_{p+1}:")
for r, v in values:
    print("root =", r, "   F_{p+1}(root) =", v)
# Out:
# F_{p+1}(x) = x^47 + 46*x^45 + 990*x^43 + 13244*x^41 + 123410*x^39 + 850668*x^37 + 4496388*x^35 + 18643560*x^33 + 61523748*x^31 + 163011640*x^29 + 348330136*x^27 + 600805296*x^25 + 834451800*x^23 + 927983760*x^21 + 818809200*x^19 + 565722720*x^17 + 300540195*x^15 + 119759850*x^13 + 34597290*x^11 + 6906900*x^9 + 888030*x^7 + 65780*x^5 + 2300*x^3 + 24*x
# F'_{p+1}(x) = 47*x^46 + 2070*x^44 + 42570*x^42 + 543004*x^40 + 4812990*x^38 + 31474716*x^36 + 157373580*x^34 + 615237480*x^32 + 1907236188*x^30 + 4727337560*x^28 + 9404913672*x^26 + 15020132400*x^24 + 19192391400*x^22 + 19487658960*x^20 + 15557374800*x^18 + 9617286240*x^16 + 4508102925*x^14 + 1556878050*x^12 + 380570190*x^10 + 62162100*x^8 + 6216210*x^6 + 328900*x^4 + 6900*x^2 + 24
# ...
